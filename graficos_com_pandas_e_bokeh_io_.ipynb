# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielxbox/projeto-com-python/blob/master/graficos_com_pandas_e_bokeh_io_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
   import pandas as pd
   from bokeh.io import output_notebook
   from bokeh.plotting import figure, show

# %%
output_notebook()

# %%
df = pd.read_csv('/content/consolidado.csv')

df.tail(9)
# Out:
#       ID   ANO         AREA  ... OBJECTID        RESUMO        LARGURA
# 1  10812  2001     10708.70  ...     2058    Artificial     443.936564
# 2  10813  2001    313524.80  ...     2059    Artificial    2510.363662
# 3  10814  2001     13082.38  ...     2060    Artificial     474.466226
# 4  10815  2001  57329300.00  ...     2061       Natural  239096.878528
# 5  10816  2001    255663.30  ...     2062    Artificial    2606.700649
# 6  10817  2001     97423.80  ...     2063    Artificial    1900.314385
# 7  10818  2001    631521.00  ...     2064    Artificial    5372.474447
# 8  10819  2001     25192.19  ...     2065    778.061236            NaN
# 9  10820  2001   1129063.00  ...     2066  10948.839735            NaN
#
# [9 rows x 7 columns]

# %% [markdown]
# # Nova seção

# %%
registros_por_ano = df[["OBJECTID", "ANO"]].groupby("ANO").count().reset_index()

registros_por_ano.columns = ["ANO", "TOTAL"]

registros_por_ano.head()
# Out:
#     ANO  TOTAL
# 0  2001     10

# %%
p = figure(plot_height = 600,
       plot_width = 600, title = 'Ocupação do solo no Munício do Rio de Janeiro', 
       x_axis_label = 'Ano', y_axis_label = 'Total de registros')

# %%
 p.vbar(top=registros_por_ano["TOTAL"], x=registros_por_ano["ANO"], width=1)
show(p)
# Out:
#   <div class="bk-root" id="54a5f230-a6e8-48dd-9228-1af04053834d" data-root-id="1001"></div>

# %%
df.CLASSE.unique()
# Out:
# array(['Campo Antrópico', 'Solo Exposto', 'Floresta', 'Urb não consolid',
#        'Área Urbana'], dtype=object)

# %%
df_Floresta = df[df.CLASSE == 'Floresta']
df_Floresta.head(10)
# Out:
#       ID   ANO        AREA    CLASSE OBJECTID   RESUMO        LARGURA
# 4  10815  2001  57329300.0  Floresta     2061  Natural  239096.878528

# %%
registros_por_ano = df_Floresta[["ANO", "OBJECTID"]].groupby("ANO").count().reset_index()
registros_por_ano.columns = ["ANO", "TOTAL"]
registros_por_ano.head()
# Out:
#     ANO  TOTAL
# 0  2001      1

# %%
  p = figure(plot_height = 400,
        plot_width = 600,
        title = 'Ocupação do solo no Munício do Rio de Janeiro',
        x_axis_label = 'Ano',
        y_axis_label = 'Total de registros')

p.vbar(top=registros_por_ano["TOTAL"], x=registros_por_ano["ANO"], width=1)
show(p)
# Out:
#   <div class="bk-root" id="c5097228-6e2b-4408-a5c1-9f1617ca4b11" data-root-id="1096"></div>

# %%
p = figure(plot_height = 400,
       plot_width = 600,
       title = 'Ocupação do solo no Munício do Rio de Janeiro',
       x_axis_label = 'Ano',
       y_axis_label = 'Total de registros')
p.line(y=registros_por_ano["TOTAL"], x=registros_por_ano["ANO"])
show(p)

p.circle(y=registros_por_ano["TOTAL"], x=registros_por_ano["ANO"], size=10)
show(p)
# Out:
#   <div class="bk-root" id="2490918a-d6b9-486c-bf60-dd603b484454" data-root-id="1310"></div>
#   <div class="bk-root" id="877edcf4-7cbb-41af-b139-fbd0ec298e5d" data-root-id="1310"></div>

# %%
area_por_ano = df_Floresta[["ANO", "AREA"]].groupby("ANO").sum().reset_index()

area_por_ano.head()
# Out:
#     ANO        AREA
# 0  2001  57329300.0

# %%
p = figure(plot_height = 400,
       plot_width = 600,
       title = 'Ocupação do solo no Munício do Rio de Janeiro',
       x_axis_label = 'Ano',
       y_axis_label = 'Área total')
p.line(y=area_por_ano["AREA"], x=area_por_ano["ANO"])
p.circle(y=area_por_ano["AREA"], x=area_por_ano["ANO"], size=5)
show(p)
# Out:
#   <div class="bk-root" id="3d0c97cd-2b20-411f-8fc5-880c9cdd1611" data-root-id="1528"></div>

# %%
area_por_total = registros_por_ano.join(area_por_ano, rsuffix='_area')

area_por_total
# Out:
#     ANO  TOTAL  ANO_area        AREA
# 0  2001      1      2001  57329300.0

# %%
area_por_total = area_por_total[["TOTAL", "AREA"]]

area_por_total
# Out:
#    TOTAL        AREA
# 0      1  57329300.0

# %%
p = figure(plot_height = 400,
      plot_width = 600,
       title = 'Ocupação do solo no Munício do Rio de Janeiro',
       x_axis_label = 'Área',
       y_axis_label = 'Total de registros')
p.line(y=area_por_total["TOTAL"], x=area_por_total["AREA"])
show(p)
# Out:
#   <div class="bk-root" id="13fe965e-d30c-48aa-9759-584b5748c5b7" data-root-id="1676"></div>
